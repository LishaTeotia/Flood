# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install overturemaps

# %%
output_path = "/content/drive/MyDrive/THESIS/OvertureMaps/mumbai_buildings.geojson"

# !mkdir -p "/content/drive/MyDrive/THESIS/OvertureMaps"
# !overturemaps download --bbox=72.75,18.88,73.00,19.30 -f geojson -t building -o "{output_path}"
